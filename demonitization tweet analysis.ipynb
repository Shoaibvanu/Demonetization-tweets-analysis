# %% [markdown]
# # Hypothesis / target to achieve in this project

# %% [markdown]
# 1. Look at the top 50 mentions in the dataset
# 2. Find the top 50 most frequently used hashtags
# 3. Find the sentence having the mations of pm
# 4. Use the prepositions to extract relevant information from the tweetseets

# %% [markdown]
# # Load the Data

# %%
import pandas as pd
import spacy
import numpy as np
import re
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("Demonatization_tweets.csv",encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#    Unnamed: 0                                               text
# 0           1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  RT @satishacharya: Reddy Wedding! @mail_today ...

# %%
text = "RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;…"

rt_remove = re.sub('RT',' ',text)

# %%
rt_remove
# Out:
# "  @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;…"

# %%
df['text']=df['text'].apply(lambda x: re.sub('RT ','',x))
df['text']=df['text'].apply(lambda x: re.sub('&amp ','&',x))
df['text']=df['text'].apply(lambda x: re.sub('<U\+[A-Z0-9]+>','',x))
df['text']=df['text'].apply(lambda x: re.sub('<ed>+','',x))

# %%
df
# Out:
#        Unnamed: 0                                               text
# 0               1  @rssurjewala: Critical question: Was PayTM inf...
# 1               2  @Hemant_80: Did you vote on #Demonetization on...
# 2               3  @roshankar: Former FinSec, RBI Dy Governor, CB...
# 3               4  @ANI_news: Gurugram (Haryana): Post office emp...
# 4               5  @satishacharya: Reddy Wedding! @mail_today car...
# ...           ...                                                ...
# 14935       14936  @saxenavishakha: Ghost of demonetization retur...
# 14936       14937  N d modi fans-d true nationalists of the count...
# 14937       14938  @bharat_builder: Lol. Demonetization has fixed...
# 14938       14939  @Stupidosaur: @Vidyut B team of BJP. CIA baby....
# 14939       14940  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...
#
# [14940 rows x 2 columns]

# %% [markdown]
# # ________________________________________________________________________________________

# %% [markdown]
# # 1. Look at the top 50 mentions in the dataset

# %%
def mention(x):
    found=re.findall(r'@\w+',x)
    if found:
        return found
    return None

# %%
arr=df['text'].apply(lambda x : mention(x))

# %%
arr
# Out:
# 0                       [@rssurjewala]
# 1                         [@Hemant_80]
# 2                         [@roshankar]
# 3                          [@ANI_news]
# 4        [@satishacharya, @mail_today]
#                      ...
# 14935                [@saxenavishakha]
# 14936                             None
# 14937                [@bharat_builder]
# 14938          [@Stupidosaur, @Vidyut]
# 14939                        [@Vidyut]
# Name: text, Length: 14940, dtype: object

# %%
mentions_arr=[]

for x in arr:
    if x != None:
        mentions_arr.extend(x)

# %%
mentions_arr[:50]
# Out:
# ['@rssurjewala',
#  '@Hemant_80',
#  '@roshankar',
#  '@ANI_news',
#  '@satishacharya',
#  '@mail_today',
#  '@DerekScissors1',
#  '@ambazaarmag',
#  '@gauravcsawant',
#  '@Joydeep_911',
#  '@sumitbhati2002',
#  '@narendramodi',
#  '@narendramodi',
#  '@Joydas',
#  '@Jaggesh2',
#  '@Atheist_Krishna',
#  '@sona2905',
#  '@Dipankar_cpiml',
#  '@roshankar',
#  '@Atheist_Krishna',
#  '@pGurus1',
#  '@roshankar',
#  '@Hemant_80',
#  '@roshankar',
#  '@Atheist_Krishna',
#  '@MahikaInfra',
#  '@narendramodi',
#  '@Swamy39',
#  '@Hemant_80',
#  '@roshankar',
#  '@kapil_kausik',
#  '@roshankar',
#  '@kapil_kausik',
#  '@AAPVind',
#  '@naam_pk',
#  '@Hemant_80',
#  '@Gadgets360',
#  '@_avenu',
#  '@DonMu',
#  '@DrGPradhan',
#  '@minimathur',
#  '@mayankjain100',
#  '@kapil_kausik',
#  '@Atheist_Krishna',
#  '@arunjaitley',
#  '@narendramodi',
#  '@kanimozhi',
#  '@roshankar',
#  '@DrGPradhan',
#  '@minimathur']

# %% [markdown]
# # Find the top 50 most frequently used hashtags

# %%
df['hashtags']=df['text'].apply(lambda x: re.findall('#\w+', x))

# %%
df[['text','hashtags']].head()
# Out:
#                                                 text  \
# 0  @rssurjewala: Critical question: Was PayTM inf...
# 1  @Hemant_80: Did you vote on #Demonetization on...
# 2  @roshankar: Former FinSec, RBI Dy Governor, CB...
# 3  @ANI_news: Gurugram (Haryana): Post office emp...
# 4  @satishacharya: Reddy Wedding! @mail_today car...
#
#                            hashtags
# 0                 [#Demonetization]
# 1                 [#Demonetization]
# 2                 [#Demonetization]
# 3                 [#demonetization]
# 4  [#demonetization, #ReddyWedding]

# %%
df['hashtags'].value_counts().head(50)
# Out:
# []                                                                      5251
# [#demonetization]                                                       2882
# [#Demonetization]                                                       2488
# [#DeMonetization]                                                        808
# [#nitishkumar, #Demonetization]                                          257
# [#India, #demo]                                                          173
# [#GLvMI]                                                                 145
# [#CorruptionFreeIndia, #Demonetization]                                  103
# [#VijayMallya]                                                            86
# [#Demonetization, #NoMoneyYaar]                                           53
# [#Demonetization, #Demonetizat]                                           47
# [#SonuNigam]                                                              47
# [#Demonetization, #Insights]                                              44
# [#demonetization, #bulletin]                                              44
# [#RatanTata, #Demonetization]                                             43
# [#boycottsnapchat]                                                        41
# [#Demonetization, #IndiaFightsCorruption]                                 41
# [#DEMONETIZATION]                                                         37
# [#IndiaFightsCorruption, #Demonetization]                                 36
# [#BlackMoney, #demonetization]                                            35
# [#Demonetization, #LifeInsurance]                                         34
# [#YouTubeIsDead]                                                          30
# [#Demonetization, #MeraDeshBadalRaha]                                     28
# [#demonetization, #India]                                                 25
# [#demonetisation, #demonetization, #RBI, #Modi]                           25
# [#TrustBJP]                                                               24
# [#Demonetization, #not]                                                   23
# [#India, #demonetization]                                                 20
# [#demonetization, #BJP]                                                   19
# [#lifehacks]                                                              19
# [#DeMonetization, #ITVideo]                                               18
# [#Doltiwal, #JaiChandKejriwal, #Demonetization]                           18
# [#Hitler, #demonetization, #Hilarious]                                    18
# [#demonetization, #NMApp]                                                 16
# [#IndiaKaDil, #Demonetization]                                            16
# [#NetasCASHIn, #DeMonetization]                                           16
# [#demonetization, #NarendraModi]                                          15
# [#Demonetization, #Modi]                                                  15
# [#Demonetization, #NoteNahiPMBadlo, #__PM_, #MayawatiNextUPCM, #BSP]      14
# [#PuthanPanam]                                                            14
# [#demonetization, #BlackMoney]                                            13
# [#Demonetization, #PMModi, #NMApp]                                        13
# [#Demonetization, #India]                                                 13
# [#demonetization, #lenders]                                               13
# [#Demonetization, #YSJagan, #Ysrcp, #NCBN, #Tdp]                          12
# [#DeMonetisation]                                                         12
# [#queue, #Demonetization]                                                 12
# [#Snapchat]                                                               12
# [#Washington, #India, #Demonetization]                                    11
# [#IncrementPremierLeague]                                                 11
# Name: hashtags, dtype: int64

# %% [markdown]
# #  3. Find the sentence having the mations of pm

# %%
# importing spacy and its matcher function
import spacy
from spacy.matcher import Matcher

# load english language model
nlp = spacy.load('en_core_web_sm',disable=['ner','textcat'])

# %%
# function to find sentences mentioning president
def find_names(text):

    names = []

    # spacy doc
    doc = nlp(text)

    # pattern
    pattern = [{'LOWER': 'modi'}]


    # Matcher class object
    matcher = Matcher(nlp.vocab)
    matcher.add("names",[pattern])

    matches = matcher(doc)

    # finding patterns in the text
    for i in range(0,len(matches)):

        # match: id, start, end
        token = doc[matches[i][1]:matches[i][2]]
        # append token to list
        names.append(str(token))

    return names

# %%
# extracting sentences with president's mentions
extracted_sentences = []
for i in range(df.shape[0]):
    extracted_sentences.append(find_names(df['text'][i]))

# storing the extracted sentences in the dataframe
df['Prime_minister'] = extracted_sentences

# %%
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           1  @rssurjewala: Critical question: Was PayTM inf...
# 1           2  @Hemant_80: Did you vote on #Demonetization on...
# 2           3  @roshankar: Former FinSec, RBI Dy Governor, CB...
# 3           4  @ANI_news: Gurugram (Haryana): Post office emp...
# 4           5  @satishacharya: Reddy Wedding! @mail_today car...
#
#                            hashtags Prime_minister
# 0                 [#Demonetization]             []
# 1                 [#Demonetization]         [Modi]
# 2                 [#Demonetization]             []
# 3                 [#demonetization]             []
# 4  [#demonetization, #ReddyWedding]             []

# %%
mention = []
for i in range(df.shape[0]):
    if df['Prime_minister'][i] != []:
        mention.append(df['Prime_minister'][i])

mention
# Out:
# [['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi', 'Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi', 'Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi', 'modi'],
#  ['MODI'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi', 'Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['MODI'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi', 'Modi'],
#  ['modi', 'Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi', 'Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi', 'Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi', 'Modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi', 'Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi', 'Modi'],
#  ['Modi', 'Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi', 'Modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi', 'modi'],
#  ['Modi'],
#  ['modi', 'modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi'],
#  ['modi'],
#  ['Modi'],
#  ['modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi', 'modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi', 'modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['modi', 'modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ['Modi'],
#  ...]

# %%
sentences_pm = []
for i in range(df.shape[0]):
    if df['Prime_minister'][i] != []:
        sentences_pm.append(df['text'][i])

sentences_pm
# Out:
# ['@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  "@NilimDutta: After much contemplation I have come to the conclusion that nothing explains Modi's #DeMonetization better than monumental\x85",
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  "@NilimDutta: After much contemplation I have come to the conclusion that nothing explains Modi's #DeMonetization better than monumental\x85",
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@sritara @GabbbarSingh @sidin \r\nPlease read alternative side of story also on #Demonetization &amp; support to PM Modi\r\nhttps://t.co/SLJoymBy1m',
#  "After much contemplation I have come to the conclusion that nothing explains Modi's #DeMonetization better than monumental stupidity.",
#  'Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.\r\n\r\nIf not for Aam Aadmi, listen to them no PM Modi?',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  "@myvotetoday: Modi's #demonetization received massive public approval. So why is opposition worried about common man and create ruckus i\x85",
#  'Modi acted against national interest. The way to cashless economy need not be #Demonetization. A badly planned move.',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@rishibagree: This is exactly how some people behaving on #demonetization \r\n\r\nSince Modi Did it lets oppose it\r\nIf Sonia Gandhi have done i\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '.@suraj_agarwal_ more bhakt abuse more Modi reduce #demonetization open pandora box everyone knows Modi has no brain everything go in drain',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  "@ajit_ranade: Not surgical strike. It's the nuclear button. This is Modi's Pokhran. Kudos #demonetization",
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '#Demonetization modi ji just like your survey,mrs. clinton  was also winning the elections in all the surveys!',
#  '@MDiplomacyWORLD: Acid test for #Modi and #BJP: #Demonetization hits #Indian life #India #banking #SouthAsia https://t.co/394uVTOM2l',
#  '@MDiplomacyWORLD: Acid test for #Modi and #BJP: #Demonetization hits #Indian life #India #banking #SouthAsia https://t.co/394uVTOM2l',
#  '@MDiplomacyWORLD: Acid test for #Modi and #BJP: #Demonetization hits #Indian life #India #banking #SouthAsia https://t.co/394uVTOM2l',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  'Acid test for #Modi and #BJP: #Demonetization hits #Indian life #India #banking #SouthAsia https://t.co/394uVTOM2l',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  'Post the #Indian currency #Demonetization move, #BJP or #Modi has garnered a huge base of #Foes and #Psychopaths... https://t.co/AZ4QUvkptF',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  'The only thing I have gained from Modi\'s #demonetization is one addiction to my Hindi vocabulary. I now know the meaning of "bewafa".\r\n#India',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  'The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hardship of the people."',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@RealZaidHamid_: #DemonetizationMythsBusted\r\nAnyone dying within 20 km radius of bank is coz of #Demonetization and Modi is directly resp\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  'Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  "'Thank You For Historic Participation,' Says PM Modi On Notes Ban Feedback https://t.co/wKTlB9C11B - \r\nMassive support to #Demonetization!!!",
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@MBQasmi: This is a simple survey at my Facebook page. This too shows mood of the nation on #demonetization Modi has asked wrong questio\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  "When u see ppl like Mamta &amp; Mayawati raising question abt #demonetization , thn anyone will be agree that it's good move by Modi #NoteBandi",
#  "Only 5 Lakhs Responses' on #Demonetization?? #Modi ji has more than 20.4 millions follower's on #Twitter &amp; approx... https://t.co/WdoITzJ7n2",
#  'This is a simple survey at my Facebook page. This too shows mood of the nation on #demonetization Modi has asked... https://t.co/AE6asWMMtB',
#  'This is a simple survey at my Facebook page. This too shows mood of the nation on #demonetization Modi has asked wr\x85 https://t.co/Hn94KBvm8J',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@UrjitPatelRBI: What do think of the #demonetisation of notes? #demonetization poll #RBI #Modi',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  'Now country is divided into two religion #Modi &amp;#AntiModi , whose riot potentially can way bigger than other riots.\r\n#Demonetization',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  'With due respect to the modi govt &amp; not meaning to offend any of his supporters,  #demonetization might be good or bad or whatever. .. tbc',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  'Narendra #Modi App #Demonetization Survey Results are out! https://t.co/eyEDJoCYmz https://t.co/oxBipqOuB8',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  "80% Indians supports PM Modi's #demonetization. All political parties raising hue and cry on this issue surrender please and let it be.",
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@YSRCParty: Chandrababu first said that Narendra Modi had implemented #Demonetization, taking his advice. Upon seeing... https://t.co/dx\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  'Before I wished someone or company deposit extra money to my account by mistake.but scary now. #demonetization #modi',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  'So far 5 lakhs asshole Bhakts found #DeMonetization #modi',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  'Hemant_80: Did you vote on #Demonetization on Modi survey app? A',
#  'If Meena Kumari was Tragedy Queen then Narendra Modi is surely Drama King. #Demonetization',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '#Modi and #BJP ties with the underworld and Mafia exposed.\r\n#Demonetization #Demonetisation https://t.co/AqJ0npFTIP',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  "Results of Modi's survey on his promotional app r as expected. This's not #PMOpinionPoll Modi just wanted to test\x85 https://t.co/73rpm3Yt5V",
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@Hemant_80: Did you vote on #Demonetization on Modi survey app?',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  "It's neither Mr. Modi nor public who made #demonetization hot, thanks to few hands full of Netas who made it grand success. #IndiaWithModi",
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t\x85',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  'Did you vote on #Demonetization on Modi survey app?',
#  '#Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t.co/y9HdyeM9wv',
#  "Do you think Narendra Modi's #Demonetization will serve its intended purpose ? https://t.co/SePbGzeB6S",
#  '@kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti\x85',
#  'Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi ban\x85 https://t.co/w8UQ81U7Zd',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  "5,00,000 people supported Modi Ji's idea. It's like taking a mug out of ocean of 130 billion. #Demonetization",
#  'Open message of #Indian #Child to Prime Minister #Modi\r\n@NarendraModi #Demonetization #Demonetisation https://t.co/Xkf8IJNoUC',
#  '@quizderek @MamataOfficial stop ur childsh acts.Indians supprt modi 4 #demonetization . u may b havin blak money dats y opposng policy.',
#  "Over 93% support #demonetization , PM Modi thanks people for 'historic participation'.\r\n@narendramodi ji ki jay ho! https://t.co/Wv8er6wDw3",
#  'Trump - Polls are rigged!\r\nModi - I know..hence I make my own!\r\nPrepare for some jaw dropping one-upmanship in next few years\r\n#Demonetization',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@aartic02: But Modi &amp; Chamchas told Terrorism wiped off after #Demonetization https://t.co/X2ME55oPks',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards\x85',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  'The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hardship of the people.',
#  'From a customer care point of view, the railway housekeeping &amp; sanitation feedback form is far superior than the Modi app on #DeMonetization',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  "Live updates: Modi's App survey result shows over 93% people support #demonetization move https://t.co/Ngf6j55rqf",
#  '@jairajp: So this #DeMonetization has been so Tragic in Implementation that modi govt is Flouting RBI rules for Banking License and Oper\x85',
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@kunfaaya @TarekFatah or is he f***ed by modi and gone mad after #demonetization',
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  '@madskak: Before the Bypolls, this will decide #Demonetization of Modi !\r\n\r\nAfter the results, Bypolls has nothing to do with #Demonetizat\x85',
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  "@JaiPoswal1995: 92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg\x85",
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@Suparna_Singh: Among most-read now: @MalikAshok on why PM Modi was placed well to move for #demonetization  https://t.co/AdqIY1zbUm',
#  "92% people support @narendramodi's #Demonetization on #Modi App &amp; insist decision should not be back \r\nhttps://t.co/2lelg33VkD\r\n@HinduRajyam",
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  'Before the Bypolls, this will decide #Demonetization of Modi !\r\nAfter the results, Bypolls has nothing to do with... https://t.co/VUhCt21bry',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  "@tweetmods: So Jaya Bachchan joins Mamata in her protest while hubby and bahu public lauded Modi's #demonetization move. Ha!",
#  "@srivatsayb @gsurya thre's no connection whatsoever betn Note ban n War,war wid Pak is already on,#Demonetization is extra pain Modi gave us",
#  '@YSRCParty: Chandrababu first said that Narendra Modi had implemented #Demonetization, taking his advice. Upon seeing... https://t.co/dx\x85',
#  'So this is basically those who have the Narendra Modi App? Why are you shocked? #demonetization https://t.co/sawbHMXmgt',
#  '@Sharmistha_GK By raising ques. on #demonetization you r raising ques. on ur father who lauded this step by Modi Ji  #DeModitisation_March',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@YSRCParty: Chandrababu first said that Narendra Modi had implemented #Demonetization, taking his advice. Upon seeing... https://t.co/dx\x85',
#  '@madskak: Before the Bypolls, this will decide #Demonetization of Modi !\r\n\r\nAfter the results, Bypolls has nothing to do with #Demonetizat\x85',
#  '#Modi wants your money. Not your opinion. #Demonetization proves it.',
#  '@YSRCParty: Chandrababu first said that Narendra Modi had implemented #Demonetization, taking his advice. Upon seeing... https://t.co/dx\x85',
#  "@uppalj: #Demonetization. Lutyens Media played negative role in PM Modi 's crusade to unearth black money. Evident which side they'd lik\x85",
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  'An idea can take your life. This must be the slogan of the #Demonetization implemented by Modi. https://t.co/1UeRiCMj7T',
#  "After #Rajini &amp; #Kamal #Mohanlal &amp; #AamirKhan comment on #Modi 's #Demonetization move\r\nhttps://t.co/T1YTGci8EZ\x85 https://t.co/VRh7uxEBcA",
#  "So Jaya Bachchan joins Mamata in her protest while hubby and bahu public lauded Modi's #demonetization move. Ha!",
#  "@anilkohli54: It's Game Set &amp; Match to PM Modi #Demonetization",
#  '@YSRCParty: Chandrababu first said that Narendra Modi had implemented #Demonetization, taking his advice. Upon seeing... https://t.co/dx\x85',
#  '@anilkohli54: . PM Modi will go to Parliament armed with millions of Indians  expressing support for #demonetization. 2N',
#  "@anilkohli54: It's Game Set &amp; Match to PM Modi #Demonetization",
#  '@YSRCParty: Chandrababu first said that Narendra Modi had implemented #Demonetization, taking his advice. Upon seeing... https://t.co/dx\x85',
#  "@deep_anchor: India's Modi Didn't Do His Homework https://t.co/RiJENeWX7y\r\n#Demonetization",
#  "@anilkohli54: It's Game Set &amp; Match to PM Modi #Demonetization",
#  '@YSRCPFriends: Chandrababu first said that Narendra Modi had implemented #Demonetization, taking his advice. Upon seeing... https://t.co\x85',
#  'Chandrababu first said that Narendra Modi had implemented #Demonetization, taking his advice. Upon seeing... https://t.co/Z1UQzh1smO #YSRcp',
#  "@anilkohli54: It's Game Set &amp; Match to PM Modi #Demonetization",
#  "@anilkohli54: It's Game Set &amp; Match to PM Modi #Demonetization",
#  'Chandrababu first said that Narendra Modi had implemented #Demonetization, taking his advice. Upon seeing... https://t.co/dxclXO3Ary',
#  "@anilkohli54: It's Game Set &amp; Match to PM Modi #Demonetization",
#  "@Rohinisgh_ET Why is the tv media not showing the truth that people are accusing Modi's #DeMonetization in real life",
#  "Godwin's law Modi-fied for the #demonetization  https://t.co/vBlxteoDNK check out our live blog as well https://t.co/fB8NEQJSJw",
#  "@anilkohli54: It's Game Set &amp; Match to PM Modi #Demonetization",
#  "It's Game Set &amp; Match to PM Modi #Demonetization",
#  "Yet another loss of life, a student suicide due to Modi's lunatic #demonetization policy https://t.co/rxTojwRbaL",
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@UrjitPatelRBI: What do think of the #demonetisation of notes? #demonetization poll #RBI #Modi',
#  'In her speech, #MamtaBanerjee Ji outlined that #demonetization was unnecessary as economy was doing good. Accidental praise for PM #Modi?',
#  "#news #summary:  #india's  #demonetization drive to help dictate  #bjp,  #modi's fortunes https://t.co/hTq4NZJBfJ",
#  "WATCH: This video of Hitler reacting to Modi's #demonetization move is hilarious! https://t.co/VVSoQS38ud via @IndianExpress",
#  '@madskak: Before the Bypolls, this will decide #Demonetization of Modi !\r\n\r\nAfter the results, Bypolls has nothing to do with #Demonetizat\x85',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@kapsology: More than 5,00,000 Indians to lose job in next 6 months due to badly planned #demonetization by Modi govt.',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@kapsology: More than 5,00,000 Indians to lose job in next 6 months due to badly planned #demonetization by Modi govt.',
#  '@kapsology: More than 5,00,000 Indians to lose job in next 6 months due to badly planned #demonetization by Modi govt.',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@kapsology: More than 5,00,000 Indians to lose job in next 6 months due to badly planned #demonetization by Modi govt.',
#  '@kapsology: More than 5,00,000 Indians to lose job in next 6 months due to badly planned #demonetization by Modi govt.',
#  '@kapsology: More than 5,00,000 Indians to lose job in next 6 months due to badly planned #demonetization by Modi govt.',
#  '@kapsology: More than 5,00,000 Indians to lose job in next 6 months due to badly planned #demonetization by Modi govt.',
#  '@kapsology: More than 5,00,000 Indians to lose job in next 6 months due to badly planned #demonetization by Modi govt.',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  'Retweeted Modi Bharosa (@ModiBharosa):\r\n\r\nHuge support for PM @narendramodi \x92s #demonetization Move Across the... https://t.co/KpCnzcWguU',
#  'Modi is the 1st PM to allow people to withdraw money through wedding card apart from debit &amp; credit card. :) #demonetization',
#  "JDU MP Harivansh backs PM Modi\x92s #demonetization move, writes Opposition's criticism of Modi Govt is irrational. https://t.co/J5T3nAM4CT",
#  "JDU MP Harivansh backs PM Modi\x92s #demonetization move, writes Opposition's criticism of Modi Govt is irrational. https://t.co/olHucpS1Zp",
#  "JDU MP Harivansh backs PM Modi\x92s #demonetization move, writes Opposition's criticism of Modi Govt is irrational. https://t.co/zucosQdqIB",
#  "JDU MP Harivansh backs PM Modi\x92s #demonetization move, writes Opposition's criticism of Modi Govt is irrational. https://t.co/br4mTdzRhR",
#  '#Demonetization is like the cash tsunami. In 15min Modi broke a delicate bond of an informal cash economy intertwined with formal economy',
#  '@anilkohli54: . PM Modi will go to Parliament armed with millions of Indians  expressing support for #demonetization. 2N',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@madskak: Before the Bypolls, this will decide #Demonetization of Modi !\r\n\r\nAfter the results, Bypolls has nothing to do with #Demonetizat\x85',
#  "@VHanumanthRao Fires on Modi's Sudden Decision \r\n#Demonetization #ModiSurgicalStrikeonCommonMan #NTVTelugu\r\n\r\nhttps://t.co/ZBPgB6XFHS",
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  "Any idea why the (super) GSampath piece on Modi and #demonetization doesn't show on @TheHindu site anymore? https://t.co/xHmYppVB2H",
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '#Demonetization \x96 good source to put your money into #training - #Modi https://t.co/crr5TKfmA2',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@OnmanoramaLive: Rahul takes on Modi, says even Jaitley kept in the dark on #demonetization\r\n\r\nRead more at: https://t.co/7hw3DGQdHV',
#  'Rahul takes on Modi, says even Jaitley kept in the dark on #demonetization\r\n\r\nRead more at: https://t.co/7hw3DGQdHV',
#  'Rahul takes on Modi, says even Jaitley kept in the dark on #demonetization\r\n\r\nRead more at: https://t.co/cji1df8DyG',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  'Narendra Modi PMO India Arun Jaitley SAY NO to Rollback of #Demonetization , yes we need better implementation... https://t.co/bv9eIUXlNn',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  "@jay_ambadi: Will an escalation on the border be Modi's answer to issues with #Demonetization? \r\nReplacing issues with graver issues?",
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  "#Demonetization. Lutyens Media played negative role in PM Modi 's crusade to unearth black money. Evident which side they'd like to butter .",
#  'life of people is become so simple thanks to modi ji otherwise just to meet the targets people was forced  #demonetization',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  'common man was in trouble before modi ji also so what modi ji has done for common men is not some thing new  #demonetization',
#  'so many years people were stuck with no jobs I still dont have job but believe in MODI Not BJP  #demonetization',
#  'Modi Ji is the only politician who think about common mans life and work hard to change in his standard  of living  #demonetization',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@jairajp: \x85and modi ji\x92s Finance Minister Jaitley Lies to the Core to Justify #DeMonetization\x85 https://t.co/gs7yLt0aws',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  "@jay_ambadi: That awkward moment when even #Swarajya find it necessary to point out Modi's mistakes on #Demonetization \r\nhttps://t.co/njH\x85",
#  'Just in:Congress leader @salman7khurshid appreciated #Demonetization, says "Kala dhan bahar lane ke is muhim me ham modi ke sath khade hain"',
#  '@Loneranger9 @narendramodi PM Modi at helm of this #demonetization scheme, should take responsibility.\r\nWhy no tweet about 80 dead ',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '@bk_chudasama: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/k1tRuxphrc',
#  '@ModiBharosa: #RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  '#RatanTata supports PM Narendra Modi for #Demonetization https://t.co/k1tRuxphrc',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '#RatanTata supports PM Narendra Modi for #Demonetization https://t.co/fRTHY2Ltth',
#  "@ajit_ranade: Not surgical strike. It's the nuclear button. This is Modi's Pokhran. Kudos #demonetization",
#  "@jay_ambadi: Will an escalation on the border be Modi's answer to issues with #Demonetization? \r\nReplacing issues with graver issues?",
#  '@madskak: Before the Bypolls, this will decide #Demonetization of Modi !\r\n\r\nAfter the results, Bypolls has nothing to do with #Demonetizat\x85',
#  '@madskak: Before the Bypolls, this will decide #Demonetization of Modi !\r\n\r\nAfter the results, Bypolls has nothing to do with #Demonetizat\x85',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  'Modi ji gave shock to common people by #Demonetization but 3 years for #Swissbank account holders. #TransformingIndia @ArvindKejriwal',
#  'Modi ji gave shock to common people by #Demonetization but 3 years for #Swissbank account holders. #TransformingIndia',
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@anilkohli54: . PM Modi will go to Parliament armed with millions of Indians  expressing support for #demonetization. 2N',
#  'Acche din aa rahe hai! We think so, do you? #BlackMoney #Demonetization #India #Modi @PMOIndia https://t.co/csg4PA1poG',
#  '@A_Observr: Very frustrated, disappointed lady. Fed up of Modi &amp; his #demonetization \r\n\r\n\r\nhttps://t.co/BTep43tvrE',
#  "@Shehzad_Ind: Bhai @KapilMishraAAP why r u surprised? #demonetization is Modi's scam not to unearth Blackmoney but to protect &amp; share it\x85",
#  '@Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r',
#  '@madskak: Before the Bypolls, this will decide #Demonetization of Modi !\r\n\r\nAfter the results, Bypolls has nothing to do with #Demonetizat\x85',
#  '@madskak: Before the Bypolls, this will decide #Demonetization of Modi !\r\n\r\nAfter the results, Bypolls has nothing to do with #Demonetizat\x85',
# ...
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@ajit_ranade @pravchak @RBI What about demonetization cited as Modi's Pokhran by u?",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  '@URautelaForever: Dear @evanspiegel \r\nIndia is so rich that PM Narendra Modi had to implement demonetization to find out who is actually\x85',
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@KambojMeenakshi: #VijayMallya\r\nAfter demonetization first modi waived off Mallya's loan and now got him bailed out\r\nIs modi Mallya's pet\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  '@URautelaForever: Dear @evanspiegel \r\nIndia is so rich that PM Narendra Modi had to implement demonetization to find out who is actually\x85',
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@KambojMeenakshi: #VijayMallya\r\nAfter demonetization first modi waived off Mallya's loan and now got him bailed out\r\nIs modi Mallya's pet\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  '@URautelaForever: Dear @evanspiegel \r\nIndia is so rich that PM Narendra Modi had to implement demonetization to find out who is actually\x85',
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  "@5Forty3: From Jan Dhan to Ujjwala to Neem coated Urea to e-Mandis to Demonetization, Modi's impact on India is historically unprecedent\x85",
#  ...]

# %%
sentences_pm[100]
# Out:
# '@Hemant_80: Did you vote on #Demonetization on Modi survey app?'

# %% [markdown]
# # 2. Use the prepositions to extract relevant information from the tweets

# %%
def rule3(text):

    doc = nlp(text)

    sent = []

    for token in doc:

        
        if (token.pos_=='VERB'):

            phrase =''

            
            for sub_tok in token.lefts:

                if (sub_tok.dep_ in ['nsubj','nsubjpass']) and (sub_tok.pos_ in ['NOUN','PROPN','PRON']):

                    
                    phrase += sub_tok.text

                    
                    phrase += ' '+token.lemma_

                    
                    for sub_tok in token.rights:

                        
                        if (sub_tok.dep_ in ['dobj']) and (sub_tok.pos_ in ['NOUN','PROPN']):

                            phrase += ' '+sub_tok.text
                            sent.append(phrase)

    return sent

# %%
row_list = []

for i in range(len(df)):

    sent = df.loc[i,'text']
    output = rule3(sent)
    dict1 = {'text':sent,'Output':output}
    row_list.append(dict1)

df_rule3 = pd.DataFrame(row_list)

# %%
df_rule3
# Out:
#                                                     text  \
# 0      @rssurjewala: Critical question: Was PayTM inf...
# 1      @Hemant_80: Did you vote on #Demonetization on...
# 2      @roshankar: Former FinSec, RBI Dy Governor, CB...
# 3      @ANI_news: Gurugram (Haryana): Post office emp...
# 4      @satishacharya: Reddy Wedding! @mail_today car...
# ...                                                  ...
# 14935  @saxenavishakha: Ghost of demonetization retur...
# 14936  N d modi fans-d true nationalists of the count...
# 14937  @bharat_builder: Lol. Demonetization has fixed...
# 14938  @Stupidosaur: @Vidyut B team of BJP. CIA baby....
# 14939  @Vidyut B team of BJP. CIA baby. CCTV, EVM but...
#
#                                                   Output
# 0                                   [PayTM inform edict]
# 1                                                     []
# 2                                                     []
# 3                           [employees provide exchange]
# 4                                                     []
# ...                                                  ...
# 14935                                                 []
# 14936  [modi think https://t.co/9mgMEFu2sl, modi thin...
# 14937      [Demonetization fix lot, pelters join crunch]
# 14938                             [CCTV support strikes]
# 14939                             [CCTV support strikes]
#
# [14940 rows x 2 columns]

# %%
df_show = pd.DataFrame(columns=df_rule3.columns)

for row in range(len(df_rule3)):

    if len(df_rule3.loc[row,'Output'])!=0:
        df_show = df_show.append(df_rule3.loc[row,:])


df_show.reset_index(inplace=True, drop=True)

# %%
df_show.head()
# Out:
#                                                 text  \
# 0  @rssurjewala: Critical question: Was PayTM inf...
# 1  @ANI_news: Gurugram (Haryana): Post office emp...
# 2  National reform now destroyed even the essence...
# 3  @Joydas: Question in Narendra Modi App where P...
# 4  @Jaggesh2 Bharat band on 28??Those who  are pr...
#
#                                         Output
# 0                         [PayTM inform edict]
# 1                 [employees provide exchange]
# 2                     [reform destroy essence]
# 3  [PM take feedback, people support strategy]
# 4                 [who protest demonetization]

# %%
prep_dict = dict()
dis_dict = dict()
dis_list = []


for i in range(len(df_show)):

    
    sentence = df_show.loc[i,'text']
   
    
    output = df_show.loc[i,'Output']


    for sent in output:

        
        n1, p, n2 = sent.split()[0], sent.split()[1], sent.split()[2:]

        
        dis_dict = {'text':text,'Noun1':n1,'Preposition':p,'Noun2':n2}
        dis_list.append(dis_dict)

        
        prep = sent.split()[1]
        if prep in prep_dict:
            prep_dict[prep]+=1
        else:
            prep_dict[prep]=1

df_sep= pd.DataFrame(dis_list)

# %%
df_sep.head()
# Out:
#                                                 text      Noun1 Preposition  \
# 0  RT @rssurjewala: Critical question: Was PayTM ...      PayTM      inform
# 1  RT @rssurjewala: Critical question: Was PayTM ...  employees     provide
# 2  RT @rssurjewala: Critical question: Was PayTM ...     reform     destroy
# 3  RT @rssurjewala: Critical question: Was PayTM ...         PM        take
# 4  RT @rssurjewala: Critical question: Was PayTM ...     people     support
#
#         Noun2
# 0     [edict]
# 1  [exchange]
# 2   [essence]
# 3  [feedback]
# 4  [strategy]

# %%
df_sep['Preposition'].value_counts()[:10]
# Out:
# @narendramodi    997
# support          610
# have             451
# inform           288
# get              265
# take             239
# claim            187
# end              157
# make             156
# give             151
# Name: Preposition, dtype: int64

# %%
df_sep[df_sep['Preposition'] == 'support'].head(10)
# Out:
#                                                   text        Noun1  \
# 4    RT @rssurjewala: Critical question: Was PayTM ...       people
# 20   RT @rssurjewala: Critical question: Was PayTM ...            %
# 22   RT @rssurjewala: Critical question: Was PayTM ...            %
# 34   RT @rssurjewala: Critical question: Was PayTM ...       people
# 45   RT @rssurjewala: Critical question: Was PayTM ...            %
# 60   RT @rssurjewala: Critical question: Was PayTM ...  nitishkumar
# 65   RT @rssurjewala: Critical question: Was PayTM ...            %
# 82   RT @rssurjewala: Critical question: Was PayTM ...            %
# 106  RT @rssurjewala: Critical question: Was PayTM ...            %
# 114  RT @rssurjewala: Critical question: Was PayTM ...            %
#
#     Preposition            Noun2
# 4       support       [strategy]
# 20      support            [ban]
# 22      support            [ban]
# 34      support       [strategy]
# 45      support            [ban]
# 60      support  [@narendramodi]
# 65      support            [ban]
# 82      support            [ban]
# 106     support            [ban]
# 114     support            [ban]
